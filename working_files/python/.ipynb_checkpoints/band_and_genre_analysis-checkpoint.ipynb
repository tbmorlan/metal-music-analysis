# %% [markdown]
# # Setup
#
# Import libraries and create dataframes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 14, 4
sns.set_style('whitegrid')

# %%
# import data
address = '../working_data/all-metal-music-cleaned.csv'
metal_df = pd.read_csv(address)

metal_df.head()
# Out:
#               artist        asin                     media  review_count  \
# 0    Cannibal Corpse  B09CH25B33                     Vinyl            97
# 1     Oranssi Pazuzu  B084DGQMZW  Audio CD,MP3 Music,Vinyl            90
# 2               Nile  B0081N9T4G        MP3 Music,Audio CD            90
# 3            Melvins  B000051753  Audio CD,MP3 Music,Vinyl            89
# 4  Dog Fashion Disco  B000EOTEFE  Audio CD,MP3 Music,Vinyl            86
#
#    star_rating                   title  year              genre
# 0          4.9      Butchered At Birth  2021  alternative metal
# 1          4.9          Mestarin Kynsi  2020  alternative metal
# 2          4.9             Ithyphallic  2007  alternative metal
# 3          4.9  Gluey Porch Treatments  2015  alternative metal
# 4          4.9                Adultery  2006  alternative metal

# %% [markdown]
# # Create graph based on data

# %%
# get sum of review count, grouped by genre
grouped = metal_df.groupby('genre')
genre_review_count = grouped.sum('review_count')

# convert genre labels to proper casing
genre_review_count.index = genre_review_count.index.str.title()

# sort values descending
genre_review_count = genre_review_count.sort_values(by='review_count', ascending=False)

# create plot based on grouped data
plot = sns.barplot(
    data=genre_review_count, 
    x='genre', 
    y='review_count',
    hue='genre',
    palette='pastel',
    errorbar=None)

# set y-axis labels
ticks = [500000, 1000000, 1500000, 2000000, 2500000, 3000000]
plot.set_yticks(ticks)
plot.set_yticklabels(ticks)

# set plot title and labels
plot.set(title='Number of Reviews For Each Genre', xlabel='Genre', ylabel='Count')

# display count above each genre, rounded
for i in plot.containers:
    plot.bar_label(i, fmt='%.0f')

# save plot as image for readme
plt.savefig('genre_comparison.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# # Create graph of band percentages per category

# %%
# group by genre and artist, count titles
groups = metal_df.groupby(['genre', 'artist']).size().reset_index(name='title_count')

print(groups.head())

# groups['percentage'] = groups.groupby('genre')['title_count'].transform(lambda x: (x / x.sum()) * 100)


'''
# get genres
genres = groups['genre'].unique()

fig, axes = plt.subplots(len(genres),1,figsize=(12, 6*len(genres)))
if len(genres)==1:
    axes = [axes]

for ax, genre in zip(axes, genres):
    genre_data = groups[groups['genre']==genre]
    sns.barplot(
        x='percentage',
        y='artist',
        data=genre_data,
        ax=ax,
        hue='genre',
        palette='pastel',
        order=genre_data.sort_values('percentage',ascending=False)['artist']
    )
    ax.set_title(f"Percentage of Titles in {genre}")
    ax.set_xlabel("Percentage")
    ax.set_ylabel("Artist")
    
plt.show()'''
